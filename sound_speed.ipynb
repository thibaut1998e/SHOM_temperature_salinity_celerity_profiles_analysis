# %%
import gsw

# %%
from utils import *
from time import time

# %%
PROFS, _, _ = get_profiles()
# Out:
# number of validation profiles 167

# %%
t = time()
for prof in PROFS:
    sound_speed = prof.get_sound_speed()
print(f'time to transform all the {len(PROFS)} profiles', time()-t)
# Out:
# time to transform all the 16730 profiles 0.9874074459075928

# %%
for i in range(10):
    prof = PROFS[i]
    sound_speed = prof.get_sound_speed()
    plt.xlabel('depth (m)')
    plt.ylabel('sound speed (m.s-1)')
    plt.plot(prof.depth, sound_speed)
    plt.show()
